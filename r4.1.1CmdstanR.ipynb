# %%
library(reticulate)
library(readr)
sagemaker <- import('sagemaker')
cmdstan_py <- import('cmdstan')

# %%
sys <- import('sys')
imp_loc <-import('imp')

# %%
sys$path
# Out:
# [1] ""
# [2] "/opt/conda/bin"
# [3] "/opt/conda/lib/python37.zip"
# [4] "/opt/conda/lib/python3.7"
# [5] "/opt/conda/lib/python3.7/lib-dynload"
# [6] "/opt/conda/lib/python3.7/site-packages"
# [7] "/opt/conda/lib/R/library/reticulate/python"

# %%
list.files('/opt/conda/lib/R/library/reticulate/python',all.files=TRUE)
# Out:
# [1] "."        ".."       "rpytools"

# %%
list.files('/opt/conda/lib/python3.7/site-packages',all.files=TRUE)
# Out:
#   [1] "__pycache__"
#   [2] "_cffi_backend.cpython-37m-x86_64-linux-gnu.so"
#   [3] "_distutils_hack"
#   [4] "_multiprocess"
#   [5] "."
#   [6] ".."
#   [7] "asn1crypto"
#   [8] "asn1crypto-1.4.0.dist-info"
#   [9] "attr"
#  [10] "attrs-21.2.0.dist-info"
#  [11] "boto3"
#  [12] "boto3-1.18.44.dist-info"
#  [13] "botocore"
#  [14] "botocore-1.21.44.dist-info"
#  [15] "brotli"
#  [16] "brotlipy-0.7.0-py3.7.egg-info"
#  [17] "certifi"
#  [18] "certifi-2021.5.30-py3.7.egg-info"
#  [19] "cffi"
#  [20] "cffi-1.14.6.dist-info"
#  [21] "chardet"
#  [22] "chardet-4.0.0.dist-info"
#  [23] "charset_normalizer"
#  [24] "charset_normalizer-2.0.0.dist-info"
#  [25] "colorama"
#  [26] "colorama-0.4.4.dist-info"
#  [27] "conda"
#  [28] "conda_env"
#  [29] "conda_package_handling"
#  [30] "conda_package_handling-1.7.3.dist-info"
#  [31] "conda-4.6.14-py3.7.egg-info"
#  [32] "cryptography"
#  [33] "cryptography-3.4.7.dist-info"
#  [34] "dateutil"
#  [35] "dill"
#  [36] "dill-0.3.4.dist-info"
# ...

# %%
list.files('/opt/conda/lib/python3.7/lib-dynload',all.files=TRUE)
# Out:
#  [1] "_asyncio.cpython-37m-x86_64-linux-gnu.so"
#  [2] "_bisect.cpython-37m-x86_64-linux-gnu.so"
#  [3] "_blake2.cpython-37m-x86_64-linux-gnu.so"
#  [4] "_bz2.cpython-37m-x86_64-linux-gnu.so"
#  [5] "_codecs_cn.cpython-37m-x86_64-linux-gnu.so"
#  [6] "_codecs_hk.cpython-37m-x86_64-linux-gnu.so"
#  [7] "_codecs_iso2022.cpython-37m-x86_64-linux-gnu.so"
#  [8] "_codecs_jp.cpython-37m-x86_64-linux-gnu.so"
#  [9] "_codecs_kr.cpython-37m-x86_64-linux-gnu.so"
# [10] "_codecs_tw.cpython-37m-x86_64-linux-gnu.so"
# [11] "_contextvars.cpython-37m-x86_64-linux-gnu.so"
# [12] "_crypt.cpython-37m-x86_64-linux-gnu.so"
# [13] "_csv.cpython-37m-x86_64-linux-gnu.so"
# [14] "_ctypes_test.cpython-37m-x86_64-linux-gnu.so"
# [15] "_ctypes.cpython-37m-x86_64-linux-gnu.so"
# [16] "_curses_panel.cpython-37m-x86_64-linux-gnu.so"
# [17] "_curses.cpython-37m-x86_64-linux-gnu.so"
# [18] "_datetime.cpython-37m-x86_64-linux-gnu.so"
# [19] "_decimal.cpython-37m-x86_64-linux-gnu.so"
# ...

# %%
list.files('/opt/conda/lib/python3.7',all.files=TRUE)
# Out:
#   [1] "__future__.py"
#   [2] "__phello__.foo.py"
#   [3] "__pycache__"
#   [4] "_bootlocale.py"
#   [5] "_collections_abc.py"
#   [6] "_compat_pickle.py"
#   [7] "_compression.py"
#   [8] "_dummy_thread.py"
#   [9] "_markupbase.py"
#  [10] "_osx_support.py"
#  [11] "_py_abc.py"
#  [12] "_pydecimal.py"
#  [13] "_pyio.py"
#  [14] "_sitebuiltins.py"
#  [15] "_strptime.py"
#  [16] "_sysconfigdata_aarch64_conda_cos7_linux_gnu.py"
#  [17] "_sysconfigdata_aarch64_conda_linux_gnu.py"
#  [18] "_sysconfigdata_i686_conda_cos6_linux_gnu.py"
#  [19] "_sysconfigdata_i686_conda_linux_gnu.py"
#  [20] "_sysconfigdata_m_linux_x86_64-linux-gnu.py"
#  [21] "_sysconfigdata_powerpc64le_conda_cos7_linux_gnu.py"
#  [22] "_sysconfigdata_powerpc64le_conda_linux_gnu.py"
#  [23] "_sysconfigdata_x86_64_apple_darwin13_4_0.py"
#  [24] "_sysconfigdata_x86_64_conda_cos6_linux_gnu.py"
#  [25] "_sysconfigdata_x86_64_conda_linux_gnu.py"
#  [26] "_threading_local.py"
#  [27] "_weakrefset.py"
#  [28] "."
#  [29] ".."
# ...

# %%
list.files('/opt/conda/bin',all.files=TRUE)
# Out:
#   [1] "__pycache__"
#   [2] "."
#   [3] ".."
#   [4] "2to3"
#   [5] "2to3-3.7"
#   [6] "acountry"
#   [7] "activate"
#   [8] "adig"
#   [9] "ahost"
#  [10] "autopoint"
#  [11] "bunzip2"
#  [12] "bzcat"
#  [13] "bzcmp"
#  [14] "bzdiff"
#  [15] "bzegrep"
#  [16] "bzfgrep"
#  [17] "bzgrep"
#  [18] "bzip2"
#  [19] "bzip2recover"
#  [20] "bzless"
#  [21] "bzmore"
#  [22] "c_rehash"
#  [23] "cairo-trace"
#  [24] "captoinfo"
#  [25] "chardetect"
#  [26] "cjpeg"
#  [27] "clear"
#  [28] "cmdstan"
#  [29] "cmdstan_model"
#  [30] "compile_et"
#  [31] "conda"
#  [32] "conda-env"
#  [33] "cph"
#  [34] "curl"
#  [35] "curl-config"
#  [36] "curve_keygen"
#  [37] "deactivate"
#  [38] "derb"
#  [39] "djpeg"
#  [40] "dltest"
#  [41] "envsubst"
#  [42] "f2py"
#  [43] "f2py3"
#  [44] "f2py3.7"
#  [45] "fax2ps"
#  [46] "fax2tiff"
#  [47] "fc-cache"
#  [48] "fc-cat"
#  [49] "fc-conflist"
#  [50] "fc-list"
#  [51] "fc-match"
#  [52] "fc-pattern"
#  [53] "fc-query"
#  [54] "fc-scan"
#  [55] "fc-validate"
# ...

# %%
list.files('/opt/conda/bin/cmdstan',all.files=TRUE)
# Out:
#  [1] "."                         ".."
#  [3] ".clang-format"             ".github"
#  [5] ".gitignore"                ".gitmodules"
#  [7] "bin"                       "build_env_setup.sh"
#  [9] "conda_build.sh"            "examples"
# [11] "install-tbb.bat"           "Jenkinsfile"
# [13] "lib"                       "LICENSE"
# [15] "make"                      "makefile"
# [17] "metadata_conda_debug.yaml" "README.md"
# [19] "runCmdStanTests.py"        "src"
# [21] "stan"                      "test-all.sh"

# %%
.libPaths()
# Out:
# [1] "/opt/conda/lib/R/library"

# %%
# we recommend running this is a fresh R session or restarting your current session
install.packages("cmdstanr", repos = c("https://mc-stan.org/r-packages/", getOption("repos")))
# Out:
# also installing the dependencies ‘tensorA’, ‘distributional’, ‘posterior’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(cmdstanr)
# Out:
# This is cmdstanr version 0.4.0
#
# - Online documentation and vignettes at mc-stan.org/cmdstanr
#
# - Use set_cmdstan_path() to set the path to CmdStan
#
# - Use install_cmdstan() to install CmdStan

# %%
set_cmdstan_path('/opt/conda/bin/cmdstan')
# Out:
# CmdStan path set to: /opt/conda/bin/cmdstan

# %%
cmdstan_version()
# Out:
# [1] "2.27.0"
