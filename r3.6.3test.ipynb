# %%
installed.packages()
# Out:
#              Package      LibPath                  Version  Priority
# askpass      askpass      /opt/conda/lib/R/library 1.1      NA
# assertthat   assertthat   /opt/conda/lib/R/library 0.2.1    NA
# backports    backports    /opt/conda/lib/R/library 1.2.1    NA
# base         base         /opt/conda/lib/R/library 3.6.3    base
# base64enc    base64enc    /opt/conda/lib/R/library 0.1-3    NA
# bit          bit          /opt/conda/lib/R/library 4.0.4    NA
# bit64        bit64        /opt/conda/lib/R/library 4.0.5    NA
# blob         blob         /opt/conda/lib/R/library 1.2.1    NA
# brew         brew         /opt/conda/lib/R/library 1.0-6    NA
# brio         brio         /opt/conda/lib/R/library 1.1.2    NA
# broom        broom        /opt/conda/lib/R/library 0.7.6    NA
# cachem       cachem       /opt/conda/lib/R/library 1.0.5    NA
# callr        callr        /opt/conda/lib/R/library 3.7.0    NA
# caret        caret        /opt/conda/lib/R/library 6.0-88   NA
# cellranger   cellranger   /opt/conda/lib/R/library 1.1.0    NA
# class        class        /opt/conda/lib/R/library 7.3-19   recommended
# cli          cli          /opt/conda/lib/R/library 2.5.0    NA
# clipr        clipr        /opt/conda/lib/R/library 0.7.1    NA
# codetools    codetools    /opt/conda/lib/R/library 0.2-18   recommended
# colorspace   colorspace   /opt/conda/lib/R/library 2.0-1    NA
# commonmark   commonmark   /opt/conda/lib/R/library 1.7      NA
# compiler     compiler     /opt/conda/lib/R/library 3.6.3    base
# conflicted   conflicted   /opt/conda/lib/R/library 1.0.4    NA
# covr         covr         /opt/conda/lib/R/library 3.5.1    NA
# cpp11        cpp11        /opt/conda/lib/R/library 0.2.7    NA
# crayon       crayon       /opt/conda/lib/R/library 1.3.4    NA
# credentials  credentials  /opt/conda/lib/R/library 1.3.0    NA
# crosstalk    crosstalk    /opt/conda/lib/R/library 1.1.1    NA
# curl         curl         /opt/conda/lib/R/library 4.3.1    NA
# data.table   data.table   /opt/conda/lib/R/library 1.14.0   NA
# ⋮            ⋮            ⋮                        ⋮        ⋮
# tidyselect   tidyselect   /opt/conda/lib/R/library 1.1.1    NA
# tidyverse    tidyverse    /opt/conda/lib/R/library 1.3.0    NA
# timeDate     timeDate     /opt/conda/lib/R/library 3043.102 NA
# tinytex      tinytex      /opt/conda/lib/R/library 0.31     NA
# tools        tools        /opt/conda/lib/R/library 3.6.3    base
# tseries      tseries      /opt/conda/lib/R/library 0.10-48  NA
# TTR          TTR          /opt/conda/lib/R/library 0.24.2   NA
# tune         tune         /opt/conda/lib/R/library 0.1.5    NA
# urca         urca         /opt/conda/lib/R/library 1.3-0    NA
# usethis      usethis      /opt/conda/lib/R/library 2.0.1    NA
# utf8         utf8         /opt/conda/lib/R/library 1.2.1    NA
# utils        utils        /opt/conda/lib/R/library 3.6.3    base
# uuid         uuid         /opt/conda/lib/R/library 0.1-4    NA
# vctrs        vctrs        /opt/conda/lib/R/library 0.3.8    NA
# viridisLite  viridisLite  /opt/conda/lib/R/library 0.4.0    NA
# waldo        waldo        /opt/conda/lib/R/library 0.2.5    NA
# warp         warp         /opt/conda/lib/R/library 0.2.0    NA
# whisker      whisker      /opt/conda/lib/R/library 0.4      NA
# withr        withr        /opt/conda/lib/R/library 2.4.2    NA
# workflows    workflows    /opt/conda/lib/R/library 0.2.2    NA
# workflowsets workflowsets /opt/conda/lib/R/library 0.0.2    NA
# xfun         xfun         /opt/conda/lib/R/library 0.23     NA
# xml2         xml2         /opt/conda/lib/R/library 1.3.2    NA
# xopen        xopen        /opt/conda/lib/R/library 1.0.0    NA
# xtable       xtable       /opt/conda/lib/R/library 1.8-4    NA
# xts          xts          /opt/conda/lib/R/library 0.12.1   NA
# yaml         yaml         /opt/conda/lib/R/library 2.2.1    NA
# yardstick    yardstick    /opt/conda/lib/R/library 0.0.8    NA
# zip          zip          /opt/conda/lib/R/library 2.1.1    NA
# zoo          zoo          /opt/conda/lib/R/library 1.8-9    NA
#              Depends
# askpass      NA
# assertthat   NA
# backports    R (>= 3.0.0)
# base         NA
# base64enc    R (>= 2.9.0)
# bit          R (>= 2.9.2)
# bit64        R (>= 3.0.1), bit (>= 4.0.0), utils, methods, stats
# blob         NA
# brew         NA
# brio         NA
# broom        R (>= 3.1)
# cachem       NA
# callr        NA
# caret        R (>= 3.2.0), lattice (>= 0.20), ggplot2
# cellranger   R (>= 3.0.0)
# class        R (>= 3.0.0), stats, utils
# cli          R (>= 2.10)
# clipr        NA
# codetools    R (>= 2.1)
# colorspace   R (>= 3.0.0), methods
# commonmark   NA
# compiler     NA
# conflicted   R (>= 3.2)
# covr         R (>= 3.1.0), methods
# cpp11        NA
# crayon       NA
# credentials  NA
# crosstalk    NA
# curl         R (>= 3.0.0)
# data.table   R (>= 3.1.0)
# ⋮            ⋮
# tidyselect   R (>= 3.2)
# tidyverse    R (>= 3.2)
# timeDate     R (>= 2.15.1), graphics, utils, stats, methods
# tinytex      NA
# tools        NA
# tseries      R (>= 2.10.0)
# TTR          NA
# tune         R (>= 2.10)
# urca         R (>= 2.0.0), methods
# usethis      R (>= 3.2)
# utf8         R (>= 2.10)
# utils        NA
# uuid         R (>= 2.9.0)
# vctrs        R (>= 3.3)
# viridisLite  R (>= 2.10)
# waldo        NA
# warp         R (>= 3.2)
# whisker      NA
# withr        R (>= 3.2.0)
# workflows    R (>= 3.2)
# workflowsets R (>= 2.10)
# xfun         NA
# xml2         R (>= 3.1.0)
# xopen        R (>= 3.1)
# xtable       R (>= 2.10.0)
# xts          zoo (>= 1.7-12)
# yaml         NA
# yardstick    R (>= 2.10)
# zip          NA
# zoo          R (>= 3.1.0), stats
#              Imports
# askpass      sys (>= 2.1)
# assertthat   tools
# backports    NA
# base         NA
# base64enc    NA
# bit          NA
# bit64        NA
# blob         methods, rlang, vctrs (>= 0.2.1)
# brew         NA
# brio         NA
# broom        backports, dplyr (>= 1.0.0), ellipsis, generics (>= 0.0.2),\nglue, methods, purrr, rlang, stringr, tibble (>= 3.0.0), tidyr\n(>= 1.0.0)
# cachem       rlang, fastmap
# callr        processx (>= 3.5.0), R6, utils
# caret        foreach, methods, plyr, ModelMetrics (>= 1.2.2.2), nlme,\nreshape2, stats, stats4, utils, grDevices, recipes (>= 0.1.10),\nwithr (>= 2.0.0), pROC,
# cellranger   rematch, tibble
# class        MASS
# cli          glue, utils
# clipr        utils
# codetools    NA
# colorspace   graphics, grDevices, stats
# commonmark   NA
# compiler     NA
# conflicted   rlang (>= 0.3.4), memoise
# covr         digest, stats, utils, jsonlite, rex, httr, crayon, withr (>=\n1.0.2), yaml
# cpp11        NA
# crayon       grDevices, methods, utils
# credentials  openssl (>= 1.3), sys (>= 2.1), curl, jsonlite, askpass
# crosstalk    htmltools (>= 0.3.6), jsonlite, lazyeval, R6
# curl         NA
# data.table   methods
# ⋮            ⋮
# tidyselect   ellipsis, glue (>= 1.3.0), purrr (>= 0.3.2), rlang (>= 0.4.6),\nvctrs (>= 0.3.0)
# tidyverse    broom (>= 0.5.2), cli (>= 1.1.0), crayon (>= 1.3.4), dbplyr\n(>= 1.4.2), dplyr (>= 0.8.3), forcats (>= 0.4.0), ggplot2 (>=\n3.2.1), haven (>= 2.2.0), hms (>= 0.5.2), httr (>= 1.4.1),\njsonlite (>= 1.6), lubridate (>= 1.7.4), magrittr (>= 1.5),\nmodelr (>= 0.1.5), pillar (>= 1.4.2), purrr (>= 0.3.3), readr\n(>= 1.3.1), readxl (>= 1.3.1), reprex (>= 0.3.0), rlang (>=\n0.4.1), rstudioapi (>= 0.10), rvest (>= 0.3.5), stringr (>=\n1.4.0), tibble (>= 2.1.3), tidyr (>= 1.0.0), xml2 (>= 1.2.2)
# timeDate     NA
# tinytex      xfun (>= 0.19)
# tools        NA
# tseries      graphics, stats, utils, quadprog, zoo, quantmod (>= 0.4-9)
# TTR          xts (>= 0.10-0), zoo, curl
# tune         cli (>= 2.0.0), dials (>= 0.0.9), dplyr (>= 1.0.0), foreach,\ngenerics (>= 0.1.0), ggplot2, glue, GPfit, parsnip (>= 0.1.4),\npurrr (>= 0.3.2), recipes (>= 0.1.15), rlang (>= 0.4.0),\nrsample (>= 0.0.9), tibble (>= 3.1.0), tidyr, vctrs (>= 0.3.0),\nworkflows (>= 0.2.2), yardstick (>= 0.0.7)
# urca         nlme, graphics, stats
# usethis      cli, clipr (>= 0.3.0), crayon, curl (>= 2.7), desc, fs (>=\n1.3.0), gert (>= 1.0.2), gh (>= 1.2.0), glue (>= 1.3.0),\njsonlite, lifecycle, purrr, rappdirs, rlang (>= 0.4.10),\nrprojroot (>= 1.2), rstudioapi, stats, utils, whisker, withr\n(>= 2.3.0), yaml
# utf8         NA
# utils        NA
# uuid         NA
# vctrs        ellipsis (>= 0.2.0), glue, rlang (>= 0.4.10)
# viridisLite  NA
# waldo        cli, diffobj, fansi, glue, methods, rematch2, rlang (>=\n0.4.10), tibble
# warp         NA
# whisker      NA
# withr        graphics, grDevices, stats
# workflows    cli (>= 2.0.0), ellipsis (>= 0.2.0), generics (>= 0.1.0),\nglue, hardhat (>= 0.1.4), parsnip (>= 0.1.5), rlang (>= 0.4.1),\ntidyselect (>= 1.1.0), vctrs (>= 0.3.6)
# workflowsets rlang, tune (>= 0.1.3), withr, dplyr (>= 1.0.0), purrr, tibble\n(>= 3.1.0), vctrs, tidyr, workflows (>= 0.2.2), cli, ggplot2,\nstats, prettyunits, rsample (>= 0.0.9), generics
# xfun         stats, tools
# xml2         methods
# xopen        processx
# xtable       stats, utils
# xts          methods
# yaml         NA
# yardstick    dplyr (>= 0.8.5), generics, pROC (>= 1.15.0), rlang (>=\n0.4.0), tidyselect, utils, vctrs (>= 0.3.6)
# zip          NA
# zoo          utils, graphics, grDevices, lattice (>= 0.20-27)
#              LinkingTo
# askpass      NA
# assertthat   NA
# backports    NA
# base         NA
# base64enc    NA
# bit          NA
# bit64        NA
# blob         NA
# brew         NA
# brio         NA
# broom        NA
# cachem       NA
# callr        NA
# caret        NA
# cellranger   NA
# class        NA
# cli          NA
# clipr        NA
# codetools    NA
# colorspace   NA
# commonmark   NA
# compiler     NA
# conflicted   NA
# covr         NA
# cpp11        NA
# crayon       NA
# credentials  NA
# crosstalk    NA
# curl         NA
# data.table   NA
# ⋮            ⋮
# tidyselect   NA
# tidyverse    NA
# timeDate     NA
# tinytex      NA
# tools        NA
# tseries      NA
# TTR          xts
# tune         NA
# urca         NA
# usethis      NA
# utf8         NA
# utils        NA
# uuid         NA
# vctrs        NA
# viridisLite  NA
# waldo        NA
# warp         NA
# whisker      NA
# withr        NA
# workflows    NA
# workflowsets NA
# xfun         NA
# xml2         NA
# xopen        NA
# xtable       NA
# xts          zoo
# yaml         NA
# yardstick    NA
# zip          NA
# zoo          NA
#              Suggests
# askpass      testthat
# assertthat   testthat, covr
# backports    NA
# base         methods
# base64enc    NA
# bit          testthat (>= 0.11.0), roxygen2, knitr, rmarkdown,\nmicrobenchmark, bit64 (>= 4.0.0), ff (>= 4.0.0)
# bit64        NA
# blob         covr, crayon, pillar (>= 1.2.1), testthat
# ...
# xml2         covr, curl, httr, knitr, magrittr, mockery, rmarkdown,\ntestthat (>= 2.1.0)
# xopen        ps, testthat
# xtable       knitr, plm, zoo, survival
# xts          timeSeries, timeDate, tseries, chron, fts, tis, RUnit
# yaml         RUnit
# yardstick    covr, crayon, ggplot2, knitr, probably (>= 0.0.6), purrr,\nrmarkdown, testthat (>= 3.0.0), tidyr
# zip          covr, processx, R6, testthat, withr
# zoo          AER, coda, chron, fts, ggplot2 (>= 3.0.0), mondate, scales,\nstinepack, strucchange, timeDate, timeSeries, tis, tseries, xts
#              Enhances License                                License_is_FOSS
# askpass      NA       MIT + file LICENSE                     NA
# assertthat   NA       GPL-3                                  NA
# backports    NA       GPL-2 | GPL-3                          NA
# base         NA       Part of R 3.6.3                        NA
# base64enc    png      GPL-2 | GPL-3                          NA
# bit          NA       GPL-2 | GPL-3                          NA
# bit64        NA       GPL-2 | GPL-3                          NA
# blob         NA       GPL-3                                  NA
# brew         NA       GPL-2                                  NA
# brio         NA       MIT + file LICENSE                     NA
# broom        NA       MIT + file LICENSE                     NA
# cachem       NA       MIT + file LICENSE                     NA
# callr        NA       MIT + file LICENSE                     NA
# caret        NA       GPL (>= 2)                             NA
# cellranger   NA       MIT + file LICENSE                     NA
# class        NA       GPL-2 | GPL-3                          NA
# cli          NA       MIT + file LICENSE                     NA
# clipr        NA       GPL-3                                  NA
# codetools    NA       GPL                                    NA
# colorspace   NA       BSD_3_clause + file LICENSE            NA
# commonmark   NA       BSD_2_clause + file LICENSE            NA
# compiler     NA       Part of R 3.6.3                        NA
# conflicted   NA       GPL-3                                  NA
# covr         NA       GPL-3                                  NA
# cpp11        NA       MIT + file LICENSE                     NA
# crayon       NA       MIT + file LICENSE                     NA
# credentials  NA       MIT + file LICENSE                     NA
# crosstalk    NA       MIT + file LICENSE                     NA
# curl         NA       MIT + file LICENSE                     NA
# data.table   NA       MPL-2.0 | file LICENSE                 NA
# ⋮            ⋮        ⋮                                      ⋮
# tidyselect   NA       MIT + file LICENSE                     NA
# tidyverse    NA       GPL-3 | file LICENSE                   NA
# timeDate     NA       GPL (>= 2)                             NA
# tinytex      NA       MIT + file LICENSE                     NA
# tools        NA       Part of R 3.6.3                        NA
# tseries      NA       GPL-2                                  NA
# TTR          quantmod GPL (>= 2)                             NA
# tune         NA       MIT + file LICENSE                     NA
# urca         NA       GPL (>= 2)                             NA
# usethis      NA       MIT + file LICENSE                     NA
# utf8         NA       Apache License (== 2.0) | file LICENSE NA
# utils        NA       Part of R 3.6.3                        NA
# uuid         NA       MIT + file LICENSE                     NA
# vctrs        NA       MIT + file LICENSE                     NA
# viridisLite  NA       MIT + file LICENSE                     NA
# waldo        NA       MIT + file LICENSE                     NA
# warp         NA       MIT + file LICENSE                     NA
# whisker      NA       GPL-3                                  NA
# withr        NA       MIT + file LICENSE                     NA
# workflows    NA       MIT + file LICENSE                     NA
# workflowsets NA       MIT + file LICENSE                     NA
# xfun         NA       MIT + file LICENSE                     NA
# xml2         NA       GPL (>= 2)                             NA
# xopen        NA       MIT + file LICENSE                     NA
# xtable       NA       GPL (>= 2)                             NA
# xts          NA       GPL (>= 2)                             NA
# yaml         NA       BSD_3_clause + file LICENSE            NA
# yardstick    NA       MIT + file LICENSE                     NA
# zip          NA       CC0                                    NA
# zoo          NA       GPL-2 | GPL-3                          NA
#              License_restricts_use OS_type MD5sum NeedsCompilation Built
# askpass      NA                    NA      NA     yes              3.6.3
# assertthat   NA                    NA      NA     no               3.6.3
# backports    NA                    NA      NA     yes              3.6.3
# base         NA                    NA      NA     NA               3.6.3
# base64enc    NA                    NA      NA     yes              3.6.3
# bit          NA                    NA      NA     yes              3.6.3
# bit64        NA                    NA      NA     yes              3.6.3
# blob         NA                    NA      NA     no               3.6.3
# brew         NA                    NA      NA     NA               3.6.3
# brio         NA                    NA      NA     yes              3.6.3
# broom        NA                    NA      NA     no               3.6.3
# cachem       NA                    NA      NA     yes              3.6.3
# callr        NA                    NA      NA     no               3.6.3
# caret        NA                    NA      NA     yes              3.6.3
# cellranger   NA                    NA      NA     no               3.6.3
# class        NA                    NA      NA     yes              3.6.3
# cli          NA                    NA      NA     no               3.6.3
# clipr        NA                    NA      NA     no               3.6.3
# codetools    NA                    NA      NA     no               3.6.3
# colorspace   NA                    NA      NA     yes              3.6.3
# commonmark   NA                    NA      NA     yes              3.6.3
# compiler     NA                    NA      NA     NA               3.6.3
# conflicted   NA                    NA      NA     no               3.6.3
# covr         NA                    NA      NA     yes              3.6.3
# cpp11        NA                    NA      NA     no               3.6.3
# crayon       NA                    NA      NA     no               3.6.3
# credentials  NA                    NA      NA     no               3.6.3
# crosstalk    NA                    NA      NA     no               3.6.3
# curl         NA                    NA      NA     yes              3.6.3
# data.table   NA                    NA      NA     yes              3.6.3
# ⋮            ⋮                     ⋮       ⋮      ⋮                ⋮
# tidyselect   NA                    NA      NA     yes              3.6.3
# tidyverse    NA                    NA      NA     no               3.6.3
# timeDate     NA                    NA      NA     no               3.6.3
# tinytex      NA                    NA      NA     no               3.6.3
# tools        NA                    NA      NA     yes              3.6.3
# tseries      NA                    NA      NA     yes              3.6.3
# TTR          NA                    NA      NA     yes              3.6.3
# tune         NA                    NA      NA     no               3.6.3
# urca         NA                    NA      NA     yes              3.6.3
# usethis      NA                    NA      NA     no               3.6.3
# utf8         NA                    NA      NA     yes              3.6.3
# utils        NA                    NA      NA     yes              3.6.3
# uuid         NA                    NA      NA     yes              3.6.3
# vctrs        NA                    NA      NA     yes              3.6.3
# viridisLite  NA                    NA      NA     no               3.6.3
# waldo        NA                    NA      NA     no               3.6.3
# warp         NA                    NA      NA     yes              3.6.3
# whisker      NA                    NA      NA     no               3.6.3
# withr        NA                    NA      NA     no               3.6.3
# workflows    NA                    NA      NA     no               3.6.3
# workflowsets NA                    NA      NA     no               3.6.3
# xfun         NA                    NA      NA     yes              3.6.3
# xml2         NA                    NA      NA     yes              3.6.3
# xopen        NA                    NA      NA     no               3.6.3
# xtable       NA                    NA      NA     no               3.6.3
# xts          NA                    NA      NA     yes              3.6.3
# yaml         NA                    NA      NA     yes              3.6.3
# yardstick    NA                    NA      NA     yes              3.6.3
# zip          NA                    NA      NA     yes              3.6.3
# zoo          NA                    NA      NA     yes              3.6.3

# %%
rownames(installed.packages())
# Out:
#   [1] "askpass"       "assertthat"    "backports"     "base"
#   [5] "base64enc"     "bit"           "bit64"         "blob"
#   [9] "brew"          "brio"          "broom"         "bslib"
#  [13] "cachem"        "callr"         "caret"         "cellranger"
#  [17] "class"         "cli"           "clipr"         "codetools"
#  [21] "colorspace"    "commonmark"    "compiler"      "conflicted"
#  [25] "covr"          "cpp11"         "crayon"        "credentials"
#  [29] "crosstalk"     "curl"          "data.table"    "datasets"
#  [33] "DBI"           "dbplyr"        "desc"          "devtools"
#  [37] "dials"         "DiceDesign"    "diffobj"       "digest"
#  [41] "dplyr"         "DT"            "dtplyr"        "ellipsis"
#  [45] "evaluate"      "fansi"         "farver"        "fastmap"
#  [49] "forcats"       "foreach"       "forecast"      "fracdiff"
#  [53] "fs"            "furrr"         "future"        "future.apply"
#  [57] "gargle"        "generics"      "gert"          "ggplot2"
#  [61] "gh"            "git2r"         "gitcreds"      "globals"
#  [65] "glue"          "googledrive"   "googlesheets4" "gower"
#  [69] "GPfit"         "graphics"      "grDevices"     "grid"
#  [73] "gtable"        "hardhat"       "haven"         "here"
#  [77] "hexbin"        "highr"         "hms"           "htmltools"
#  [81] "htmlwidgets"   "httpuv"        "httr"          "ids"
#  [85] "infer"         "ini"           "ipred"         "IRdisplay"
#  [89] "IRkernel"      "isoband"       "iterators"     "jquerylib"
#  [93] "jsonlite"      "KernSmooth"    "knitr"         "labeling"
#  [97] "later"         "lattice"       "lava"          "lazyeval"
# [101] "lhs"           "lifecycle"     "listenv"       "lmtest"
# [105] "lubridate"     "magrittr"      "markdown"      "MASS"
# [109] "Matrix"        "memoise"       "methods"       "mgcv"
# [113] "mime"          "modeldata"     "ModelMetrics"  "modelr"
# [117] "munsell"       "nlme"          "nnet"          "numDeriv"
# [121] "openssl"       "parallel"      "parallelly"    "parsnip"
# [125] "patchwork"     "pbdZMQ"        "pillar"        "pkgbuild"
# [129] "pkgconfig"     "pkgload"       "plogr"         "plyr"
# [133] "png"           "praise"        "prettyunits"   "pROC"
# [137] "processx"      "prodlim"       "progress"      "progressr"
# [141] "promises"      "ps"            "purrr"         "quadprog"
# [145] "quantmod"      "R6"            "rappdirs"      "rcmdcheck"
# [149] "RColorBrewer"  "Rcpp"          "RcppArmadillo" "readr"
# [153] "readxl"        "recipes"       "rematch"       "rematch2"
# [157] "remotes"       "repr"          "reprex"        "reshape2"
# [161] "reticulate"    "rex"           "rlang"         "rmarkdown"
# [165] "RODBC"         "roxygen2"      "rpart"         "rprojroot"
# [169] "rsample"       "RSQLite"       "rstudioapi"    "rversions"
# [173] "rvest"         "sass"          "scales"        "selectr"
# [177] "sessioninfo"   "shiny"         "slider"        "sourcetools"
# [181] "splines"       "SQUAREM"       "stats"         "stats4"
# [185] "stringi"       "stringr"       "survival"      "sys"
# [189] "tcltk"         "testthat"      "tibble"        "tidymodels"
# [193] "tidyr"         "tidyselect"    "tidyverse"     "timeDate"
# [197] "tinytex"       "tools"         "tseries"       "TTR"
# [201] "tune"          "tzdb"          "urca"          "usethis"
# [205] "utf8"          "utils"         "uuid"          "vctrs"
# [209] "viridisLite"   "vroom"         "waldo"         "warp"
# [213] "whisker"       "withr"         "workflows"     "workflowsets"
# [217] "xfun"          "xml2"          "xopen"         "xtable"
# [221] "xts"           "yaml"          "yardstick"     "zip"
# [225] "zoo"

# %%
version
# Out:
#                _
# platform       x86_64-conda-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          4
# minor          1.1
# year           2021
# month          08
# day            10
# svn rev        80725
# language       R
# version.string R version 4.1.1 (2021-08-10)
# nickname       Kick Things

# %%
# we recommend running this is a fresh R session or restarting your current session
install.packages("cmdstanr", repos = c("https://mc-stan.org/r-packages/", getOption("repos")))
# Out:
# also installing the dependencies ‘tensorA’, ‘distributional’, ‘posterior’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library("cmdstanr")
# Out:
# This is cmdstanr version 0.4.0
#
# - Online documentation and vignettes at mc-stan.org/cmdstanr
#
# - Use set_cmdstan_path() to set the path to CmdStan
#
# - Use install_cmdstan() to install CmdStan

# %%
# tensorA
# distributional
# posterior
